# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('AID_2100_datatable_active.xlsx')

# %%
df.describe()
# Out:
#        PUBCHEM_RESULT_TAG   PUBCHEM_SID   PUBCHEM_CID  PUBCHEM_ACTIVITY_SCORE  \
# count         1169.000000  1.169000e+03  1.169000e+03             1169.000000
# mean           585.000000  1.834033e+07  1.959018e+07               46.102652
# std            337.605539  1.312175e+07  4.234668e+07               10.065185
# min              1.000000  8.423310e+05  7.200000e+01               40.000000
# 25%            293.000000  7.974437e+06  9.379770e+05               40.000000
# 50%            585.000000  1.741111e+07  2.940433e+06               41.000000
# 75%            877.000000  2.481268e+07  7.338023e+06               43.000000
# max           1169.000000  8.965011e+07  1.358298e+08               92.000000
#
#        PUBCHEM_ACTIVITY_URL  PUBCHEM_ASSAYDATA_COMMENT      Potency  \
# count                   0.0                        0.0  1169.000000
# mean                    NaN                        NaN    17.550214
# ...

# %%
x = df.drop(columns = ['PUBCHEM_ACTIVITY_URL', 'PUBCHEM_SID', 'PUBCHEM_CID', 'Analysis Comment'])
x.head
# Out:
# <bound method NDFrame.head of       PUBCHEM_RESULT_TAG PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  \
# 0                      1                   Active                      41
# 1                      2                   Active                      40
# 2                      3                   Active                      40
# 3                      4                   Active                      41
# 4                      5                   Active                      42
# ...                  ...                      ...                     ...
# 1164                1165                   Active                      88
# 1165                1166                   Active                      82
# 1166                1167                   Active                      42
# 1167                1168                   Active                      85
# 1168                1169                   Active                      82
#
# ...

# %%
df.head()
# Out:
#    PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME  \
# 0                   1       842331       644590                   Active
# 1                   2       842337       644595                   Active
# 2                   3       842485      6603456                   Active
# 3                   4       842488      2897066                   Active
# 4                   5       842568       644837                   Active
#
#    PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  PUBCHEM_ASSAYDATA_COMMENT  \
# 0                      41                   NaN                        NaN
# 1                      40                   NaN                        NaN
# 2                      40                   NaN                        NaN
# 3                      41                   NaN                        NaN
# 4                      42                   NaN                        NaN
#
#    Phenotype  Potency  Efficacy  ...  Fit_CurveClass Excluded_Points  \
# ...
